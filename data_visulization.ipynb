# %%
import pandas as pd 
df = pd.read_csv('rawdata.csv')

# %%
df
# Out:
#               ppg  respiration       mri
# 0       -0.137939    -0.026856  0.075989
# 1       -0.137939    -0.026856  0.076294
# 2       -0.137939    -0.026856  0.075989
# 3       -0.137939    -0.026856  0.075684
# 4       -0.137939    -0.026856  0.075989
# ...           ...          ...       ...
# 8239137       NaN          NaN  0.072022
# 8239138       NaN          NaN  0.072937
# 8239139       NaN          NaN  0.072632
# 8239140       NaN          NaN  0.072937
# 8239141       NaN          NaN  0.072632
#
# [8239142 rows x 3 columns]

# %%
type(df['ppg'])
# Out:
# pandas.core.series.Series

# %%
# set the length of data
seg = df[0:7000000]

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import pylab
from pylab import *

fig, (ax1, ax2, ax3) = plt.subplots(3,1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)



dt = 0.01
t = np.arange(0, len(seg)/100, dt)
ax1.plot(t,seg['ppg'])
ax2.plot(t,seg['respiration'])
ax3.plot(t,seg['mri'])
plt.show()

# %%
seg_1 = df[5400000:5550000]

fig, (ax4, ax5, ax6) = plt.subplots(3,1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)



dt = 0.01
t = np.arange(54000, 55500, dt)
ax4.plot(t,seg_1['ppg'])
ax5.plot(t,seg_1['respiration'])
ax6.plot(t,seg_1['mri'])
plt.show()
