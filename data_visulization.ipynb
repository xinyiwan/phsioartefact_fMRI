# %%
import pandas as pd 
df = pd.read_csv('data.csv')

# %%
df
# Out:
#               ppg  respiration       mri
# 0       -0.137939    -0.026856  0.075989
# 1       -0.137939    -0.026856  0.076294
# 2       -0.137939    -0.026856  0.075989
# 3       -0.137939    -0.026856  0.075684
# 4       -0.137939    -0.026856  0.075989
# ...           ...          ...       ...
# 6999995 -0.023804     0.019836  0.073853
# 6999996 -0.023804     0.019836  0.073547
# 6999997 -0.023804     0.019836  0.073242
# 6999998 -0.023804     0.019836  0.073242
# 6999999 -0.023804     0.019836  0.073242
#
# [7000000 rows x 3 columns]

# %%
type(df['ppg'])
# Out:
# pandas.core.series.Series

# %%
# set the length of data
seg = df[0:7000000]

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import pylab
from pylab import *

fig, (ax1, ax2, ax3) = plt.subplots(3,1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)



dt = 0.01
t = np.arange(0, 70000, dt)
ax1.plot(t,seg['ppg'])
ax2.plot(t,seg['respiration'])
ax3.plot(t,seg['mri'])
plt.show()

# %%
seg_1 = df[5520000:5550000]

fig, (ax4, ax5, ax6) = plt.subplots(3,1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)



dt = 0.01
t = np.arange(55200, 55500, dt)
ax4.plot(t,seg_1['ppg'])
ax5.plot(t,seg_1['respiration'])
ax6.plot(t,seg_1['mri'])
plt.show()
